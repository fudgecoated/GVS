# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ('~/Documents/School/GVS/DataCleanUp/DB_NORMALNGVS_JULY242022_OCULUS.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
df.columns = ['HeadQX', 'HeadQY', 'HeadQZ', 'HeadQW', 'HeadX', 'HeadY', 'HeadZ', 'HandX', 'HandY', 'HandZ', 'Time']

# %%
df['Time'] = df["Time"].str.replace("Day: ", "")
df['Time'] = df["Time"].str.replace("Time: ", "")
df['gX'] = df["gX"].str.replace("gX:", "")

# %%
df
# Out:
#         HeadQX    HeadQY    HeadQZ    HeadQW         HeadX     HeadY  \
# 0     0.089123  0.123673  0.011082  0.988251  1.966775e-03  1.221678
# 1     0.089452  0.123608  0.011170  0.988228  1.943832e-03  1.221620
# 2     0.089722  0.123657  0.011369  0.988195  1.885270e-03  1.221622
# 3     0.089750  0.123710  0.011552  0.988184  1.824410e-03  1.221599
# 4     0.090065  0.123680  0.011762  0.988156  1.805863e-03  1.221571
# 5     0.090347  0.123628  0.011711  0.988138  1.780719e-03  1.221541
# 6     0.090411  0.123608  0.011934  0.988132  1.749033e-03  1.221531
# 7     0.090091  0.123587  0.011917  0.988164  1.697122e-03  1.221519
# 8     0.090220  0.123416  0.012026  0.988172  1.650730e-03  1.221525
# 9     0.090445  0.123376  0.012134  0.988155  1.651176e-03  1.221517
# 10    0.090612  0.123335  0.012089  0.988146  1.637354e-03  1.221484
# 11    0.090732  0.123354  0.012003  0.988133  1.591885e-03  1.221448
# 12    0.091103  0.123352  0.012047  0.988099  1.552468e-03  1.221392
# ...
